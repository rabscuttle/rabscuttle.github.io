# %%
import pandas as pd

#Bring in dataset
cities_data = pd.read_csv("resources/zoo.csv")

#Change index to animal name
cities_data.set_index('animal_name', inplace=True)
cities_data.head()
# Out:
#                       hair  feathers  eggs  milk  airborne  aquatic  predator  \
# animal_name
# Aardvark                 1         0     0     1         0        0         1
# Adder                    0         0     1     0         0        0         1
# Alcatrazes Tree Frog     0         0     1     0         0        1         0
# Alligator                0         0     1     0         0        1         1
# Amazon River Dolphin     0         0     0     1         0        1         1
#
#                       toothed  backbone  breathes  venomous  fins  legs  tail  \
# animal_name
# Aardvark                    1         1         1         0     0     4     0
# Adder                       1         1         1         1     0     0     1
# Alcatrazes Tree Frog        0         1         1         0     0     4     0
# Alligator                   1         1         1         0     0     4     1
# Amazon River Dolphin        1         1         1         0     1     0     1
#
#                       domestic  catsize  class_type      class
# animal_name
# Aardvark                     0        1           1     Mammal
# Adder                        0        1           3    Reptile
# Alcatrazes Tree Frog         0        0           5  Amphibian
# Alligator                    0        1           3    Reptile
# Amazon River Dolphin         0        0           1     Mammal

# %%
#Convert to html and save to text file
cities_data.to_html(open('zoo.txt', 'w'))
