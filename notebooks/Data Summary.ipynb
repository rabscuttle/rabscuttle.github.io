# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import seaborn as sns

# %%
# Get CSV file
zoo = pd.read_csv(os.path.join('..','Resources', 'zoo.csv'))
character_results = pd.read_csv(os.path.join('..','Resources', 'character_results.csv'))
class_counts = pd.read_csv(os.path.join('..','Resources', 'class_count.csv'))
neural_networks_summary = pd.read_csv(os.path.join('..','Resources', 'neural_networks_summary.csv'))
summary_scores_numberwrong = pd.read_csv(os.path.join('..','Resources', 'summaryscores_and_numberwrong.csv'))

# %%
zoo_df=zoo.set_index('animal_name')
zoo_df
# Out:
#                             hair  feathers  eggs  milk  airborne  aquatic  \
# animal_name
# Aardvark                       1         0     0     1         0        0
# Adder                          0         0     1     0         0        0
# Alcatrazes Tree Frog           0         0     1     0         0        1
# Alligator                      0         0     1     0         0        1
# Amazon River Dolphin           0         0     0     1         0        1
# ...                          ...       ...   ...   ...       ...      ...
# Wolf                           1         0     0     1         0        0
# Woolly Monkey                  1         0     0     1         0        0
# Worm                           0         0     1     0         0        0
# Wren                           0         1     1     0         1        0
# Yellowspotted River Turtle     0         0     1     0         0        1
#
#                             predator  toothed  backbone  breathes  venomous  \
# animal_name
# Aardvark                           1        1         1         1         0
# Adder                              1        1         1         1         1
# Alcatrazes Tree Frog               0        0         1         1         0
# Alligator                          1        1         1         1         0
# Amazon River Dolphin               1        1         1         1         0
# ...                              ...      ...       ...       ...       ...
# Wolf                               1        1         1         1         0
# Woolly Monkey                      0        1         1         1         0
# Worm                               0        0         0         1         0
# Wren                               0        0         1         1         0
# Yellowspotted River Turtle         0        0         1         1         0
#
#                             fins  legs  tail  domestic  catsize  class_type  \
# animal_name
# Aardvark                       0     4     0         0        1           1
# Adder                          0     0     1         0        1           3
# Alcatrazes Tree Frog           0     4     0         0        0           5
# Alligator                      0     4     1         0        1           3
# Amazon River Dolphin           1     0     1         0        0           1
# ...                          ...   ...   ...       ...      ...         ...
# Wolf                           0     4     1         0        1           1
# Woolly Monkey                  0     4     1         0        0           1
# Worm                           0     0     0         0        0           7
# Wren                           0     2     1         0        0           2
# Yellowspotted River Turtle     0     4     0         1        0           3
#
#                                    class
# animal_name
# Aardvark                          Mammal
# Adder                            Reptile
# Alcatrazes Tree Frog           Amphibian
# Alligator                        Reptile
# Amazon River Dolphin              Mammal
# ...                                  ...
# Wolf                              Mammal
# Woolly Monkey                     Mammal
# Worm                        Invertebrate
# Wren                                Bird
# Yellowspotted River Turtle       Reptile
#
# [212 rows x 18 columns]

# %%
character_results_df=character_results.set_index('Character')
character_results_df
# Out:
#                       Logistical Regression Random Forest           KNN  \
# Character
# Kangaroo                             Mammal        Mammal        Mammal
# Bald Eagle                             Bird          Bird          Bird
# Rattle Snake                        Reptile       Reptile       Reptile
# Gold Fish                              Fish          Fish          Fish
# Mountain Chicken Frog             Amphibian     Amphibian     Amphibian
# Vampire Moth                            Bug           Bug           Bug
# Coral                          Invertabrate  Invertabrate  Invertabrate
# Sea Turtle                          Reptile          Fish          Fish
#
#                                 SVM Neural Network Deep Neural Network  \
# Character
# Kangaroo                     Mammal         Mammal              Mammal
# Bald Eagle                     Bird           Bird                Bird
# Rattle Snake                Reptile        Reptile             Reptile
# Gold Fish                      Fish           Fish                Fish
# Mountain Chicken Frog     Amphibian      Amphibian           Amphibian
# Vampire Moth                    Bug            Bug                 Bug
# Coral                  Invertabrate   Invertabrate        Invertabrate
# Sea Turtle                  Reptile        Reptile             Reptile
#
#                            Unsupervised K-Means
# Character
# Kangaroo                                 Mammal
# Bald Eagle                                 Bird
# Rattle Snake           Reptile and Invertebrate
# Gold Fish                                  Fish
# Mountain Chicken Frog     Amphibian and Reptile
# Vampire Moth                                Bug
# Coral                  Reptile and Invertebrate
# Sea Turtle                Amphibian and Reptile

# %%
class_counts_df=class_counts.set_index('Class')
class_counts_df
# Out:
#               Count
# Class
# Mammal           59
# Bird             40
# Fish             28
# Bug              25
# Reptile          24
# Invertebrate     20
# Amphibian        16
# Total           212

# %%
class_counts_df= class_counts_df.drop("Total")
class_counts_df.plot(kind='bar', title ="Number of Animals in Each Class", color="brown")
plt.show()

# %%
neural_networks_summary_df=neural_networks_summary.set_index('Model')
neural_networks_summary_df
# Out:
#                        Loss  Accuracy  Incorrect  Loss Scaled  \
# Model
# Neural Network       0.1594    0.9623        2.0       0.1486
# Deep Neural Network  0.3654    0.9623        NaN       0.2109
#
#                      Accuracy Scaled  Incorrect Scaled
# Model
# Neural Network                0.9623              16.0
# Deep Neural Network           0.9434               NaN

# %%
model_summary_df=summary_scores_numberwrong.set_index('Model')
model_summary_df
# Out:
#                      Training Score/Accuracy  Testing Score/Accuracy  \
# Model
# Logistic Regression                 0.981132                0.943396
# Random Forest                       0.987421                0.943396
# KNN                                 0.918000                0.887000
# SVM                                 0.981000                0.943000
#
#                      Incorrect  Scaled Training Score/Accuracy  \
# Model
# Logistic Regression          4                        0.987421
# Random Forest                1                        0.987421
# KNN                          6                        0.931000
# SVM                          3                        0.969000
#
#                      Scaled Testing Score/Accuracy  Scale Incorrect
# Model
# Logistic Regression                       0.962264                8
# Random Forest                             0.943396                2
# KNN                                       0.906000                6
# SVM                                       0.943000                3

# %%
#Summary of Incorrect
incorrect_df = model_summary_df[["Incorrect", "Scale Incorrect"]]
incorrect_df
# Out:
#                      Incorrect  Scale Incorrect
# Model
# Logistic Regression          4                8
# Random Forest                1                2
# KNN                          6                6
# SVM                          3                3

# %%
#Correlation Heatmap
zoo = zoo.drop(["class_type"], axis=1)
corr = zoo.iloc[:,1:-1].corr()
colormap = sns.diverging_palette(150, 250, as_cmap = True)
plt.figure(figsize=(14,14))
sns.heatmap(corr, cbar = True,  square = True, annot=True, fmt= '.2f',annot_kws={'size': 12},
            cmap = colormap, linewidths=0.1, linecolor='white')
plt.title('Correlation of ZOO Features', y=1.05, size=15) 

#plt.savefig('../resources/heat_map.png')
plt.show()

# %%
##Make Tables?
